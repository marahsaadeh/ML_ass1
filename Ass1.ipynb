# %%
import pandas as pd
import glob
import os
import urllib.request
import os.path
import numpy as np
#from bs4 import BeautifulSoup

# %%
os.chdir(r'C:\Users\shahrouri tech\Desktop\ML_Ass1\data')

# %%
all_files = glob.glob('*.txt')  
# get all files from data folder

# %%
#print(all_files)

# %%
c=0
for index in all_files:
    c=c+1
print(c)
# Out:
# 6864

# %%
len(all_files)
# Out:
# 6864

# %%
ww=open('filename.txt','r')
for index in ww:
       valid=ww.read().splitlines()
len(valid)

# %%
########all_files#########
# delete any invalid files
for file in all_files:
    if file not in valid:
        os.remove(file)

# %%
c=0
for index in all_files:
    c=c+1
print(c)
# Out:
# 6864

# %%
#df1 empty table
df1=pd.DataFrame(columns=['لون السيارة','نوع الوقود','أصل السيارة','رخصة السيارة','نوع الجير','الزجاج','قوة الماتور','عداد السيارة','عدد الركاب','وسيلة الدفع','معروضة','أصحاب سابقون','إضافات','سنة الاصدار','سعر السيارة بالشيكل']) 
df1
# Out:
# Empty DataFrame
# Columns: [لون السيارة, نوع الوقود, أصل السيارة, رخصة السيارة, نوع الجير, الزجاج, قوة الماتور, عداد السيارة, عدد الركاب, وسيلة الدفع, معروضة, أصحاب سابقون, إضافات, النوع, سنة الاصدار, سعر السيارة بالشيكل]
# Index: []

# %%
url=all_files[555] 
##tabels in this file
table_list=pd.io.html.read_html(url)
df22=table_list[4]
df22
# Out:
#            الصفة                                              الوصف
# 0    لون السيارة                                               أبيض
# 1     نوع الوقود                                               ديزل
# 2    أصل السيارة                                              خصوصي
# 3   رخصة السيارة                                           فلسطينية
# 4      نوع الجير                                               عادي
# 5         الزجاج                                           الكتروني
# 6    قوة الماتور                                               1900
# 7     عدد الركاب                                                4+1
# 8    وسيلة الدفع                                    إمكانية التقسيط
# 9         معروضة                                          للبيع فقط
# 10  أصحاب سابقون                                           يد ثالثه
# 11        إضافات  مُكيّف  إغلاق مركزي  جهاز إنذار  مسجل CD  جنطا...

# %%
i=0
while i<len(all_files):
    #
    url=all_files[i] 
#tabels in this file
    table_list=pd.io.html.read_html(url)
    df2=table_list[4]
    
    df4=table_list[3]
    adding_string=df4.iloc[0][0]
    model=''
    for k in adding_string.split():
        if k == 'موديل':
            break
        model= model +""+k
    rees = [int(i) for i in adding_string.split() if i.isdigit()]
    year=rees[-1]
    df1.loc[i,'سنة الاصدار']=year
    df1.loc[i,'موديل']=model
    j=0
    while j<len(df2):
        if df2.loc[j,'الصفة']=='لون السيارة':
            df1.loc[i,'لون السيارة']=df2.loc[j,'الوصف']
        if df2.loc[j,'الصفة']=='نوع الوقود':
            df1.loc[i,'نوع الوقود']=df2.loc[j,'الوصف']
        if df2.loc[j,'الصفة']=='أصل السيارة':
            df1.loc[i,'أصل السيارة']=df2.loc[j,'الوصف']
        if df2.loc[j,'الصفة']=='رخصة السيارة':
            df1.loc[i,'رخصة السيارة']=df2.loc[j,'الوصف']
        if df2.loc[j,'الصفة']=='نوع الجير':
            df1.loc[i,'نوع الجير']=df2.loc[j,'الوصف']
        if df2.loc[j,'الصفة']=='الزجاج':
            df1.loc[i,'الزجاج']=df2.loc[j,'الوصف']
        if df2.loc[j,'الصفة']=='قوة الماتور':
            df1.loc[i,'قوة الماتور']=df2.loc[j,'الوصف']
        if df2.loc[j,'الصفة']=='عداد السيارة':
            df1.loc[i,'عداد السيارة']=df2.loc[j,'الوصف']
        if df2.loc[j,'الصفة']=='عدد الركاب':
            df1.loc[i,'عدد الركاب']=df2.loc[j,'الوصف']
        if df2.loc[j,'الصفة']=='وسيلة الدفع':
            df1.loc[i,'وسيلة الدفع']=df2.loc[j,'الوصف']
        if df2.loc[j,'الصفة']=='إضافات':
            df1.loc[i,'إضافات']=df2.loc[j,'الوصف']
        if df2.loc[j,'الصفة']=='معروضة':
            df1.loc[i,'معروضة']=df2.loc[j,'الوصف']
        if df2.loc[j,'الصفة']=='أصحاب سابقون':
            df1.loc[i,'أصحاب سابقون']=df2.loc[j,'الوصف']
        j=j+1
    #string price and description
    string_price=table_list[3].iloc[0,1]
#int price list
    price_list=[int(i)for i in string_price.split() if i.isdigit()]
#change list into single int 
    var = ' '  
    for element in price_list: 
        var += str(element)
    price=int(var)
    df1.loc[i,'سعر السيارة بالشيكل']=price
    i=i+1
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [123], in <cell line: 2>()
#       4     url=all_files[i]
#       5 #tabels in this file
# ----> 6     table_list=pd.io.html.read_html(url)
#       7     df2=table_list[4]
#       9     df4=table_list[3]
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
len(df1)
# Out:
# 6863

# %%
df1
# Out:
#      لون السيارة نوع الوقود أصل السيارة رخصة السيارة      نوع الجير    الزجاج  \
# 0           سكني       ديزل       خصوصي     فلسطينية  نصف اوتوماتيك  الكتروني
# 1           سكني      بنزين       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# 2            بيج      بنزين       خصوصي     فلسطينية           عادي      يدوي
# 3            فضي      بنزين       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# 4           أسود       ديزل       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# ...          ...        ...         ...          ...            ...       ...
# 6858      فيراني     كهرباء       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# 6859        أبيض       ديزل       عمومي     فلسطينية           عادي  الكتروني
# 6860         فضي       ديزل       خصوصي     فلسطينية           عادي  الكتروني
# 6861      بترولي       ديزل       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# 6862        أبيض       ديزل       عمومي     فلسطينية           عادي  الكتروني
#
# ...

# %%
df1.to_csv('my_new_file2.csv',index=False)

# %%
##############_start_###########################
import pandas as pd
import glob
import os
import urllib.request
import os.path
import numpy as np

# %%
os.chdir(r'C:\Users\shahrouri tech\Desktop\ML_Ass1\data')

# %%
all_files = glob.glob('*.txt') 
len(all_files)
# Out:
# 6864

# %%
df=pd.read_csv('my_new_file2.csv')
df
# Out:
#      لون السيارة نوع الوقود أصل السيارة رخصة السيارة      نوع الجير    الزجاج  \
# 0           سكني       ديزل       خصوصي     فلسطينية  نصف اوتوماتيك  الكتروني
# 1           سكني      بنزين       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# 2            بيج      بنزين       خصوصي     فلسطينية           عادي      يدوي
# 3            فضي      بنزين       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# 4           أسود       ديزل       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# ...          ...        ...         ...          ...            ...       ...
# 6858      فيراني     كهرباء       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# 6859        أبيض       ديزل       عمومي     فلسطينية           عادي  الكتروني
# 6860         فضي       ديزل       خصوصي     فلسطينية           عادي  الكتروني
# 6861      بترولي       ديزل       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# 6862        أبيض       ديزل       عمومي     فلسطينية           عادي  الكتروني
#
# ...

# %%
# coding: utf-8
import re

# Attention: while the characters for the strings bellow are 
# dislplayed indentically, inside they are represented
# by distinct unicode codepoints

persian_numbers = u'۱۲۳۴۵۶۷۸۹۰'
arabic_numbers  = u'١٢٣٤٥٦٧٨٩٠'
english_numbers = u'1234567890'


arabic_regexp = u"(%s)" % u"|".join(arabic_numbers)


def _sub_arabic(match_object):
    return _sub(match_object, arabic_numbers)



def replace_arabic(text):
    return re.sub(arabic_regexp, _sub_arabic, text)

arabic_numbers  = '١٢٣٤٥٦٧٨٩٠'
arabic_numbers=int(arabic_numbers)
#arabic_numbers

a='٨٠٠٠٠000'
a=int(a)
a
# Out:
# 80000000

# %%
#number Nan for each column
df.isna().sum()
# Out:
# لون السيارة               0
# نوع الوقود                0
# أصل السيارة               0
# رخصة السيارة              0
# نوع الجير                 0
# الزجاج                    0
# قوة الماتور               0
# عداد السيارة           1941
# عدد الركاب              777
# وسيلة الدفع               0
# معروضة                    0
# أصحاب سابقون           1650
# إضافات                  501
# سنة الاصدار               0
# سعر السيارة بالشيكل       0
# موديل                     0
# dtype: int64

# %%
#the sum of NaN value in DataFrame
df.isna().sum().sum()
# Out:
# 4869

# %%
#fill
#fill nan -> 999
df= df.fillna({'عداد السيارة':'99999'})
#mean after change to int


df= df.fillna({'إضافات':'missing'})

# %%
#df= df.fillna({'أصحاب سابقون':'999'})
df['أصحاب سابقون']= df['أصحاب سابقون'].fillna(method='bfill')

# %%
df['عدد الركاب']= df['عدد الركاب'].fillna(method='bfill')

# %%
#000 ((bfill))
df.loc[747,'عدد الركاب']='4+1'
#+1 ((bfill))
df.loc[144,'عدد الركاب']='4+1'

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df
# Out:
#      لون السيارة نوع الوقود أصل السيارة رخصة السيارة      نوع الجير    الزجاج  \
# 0           سكني       ديزل       خصوصي     فلسطينية  نصف اوتوماتيك  الكتروني
# 1           سكني      بنزين       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# 2            بيج      بنزين       خصوصي     فلسطينية           عادي      يدوي
# 3            فضي      بنزين       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# 4           أسود       ديزل       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# ...          ...        ...         ...          ...            ...       ...
# 6858      فيراني     كهرباء       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# 6859        أبيض       ديزل       عمومي     فلسطينية           عادي  الكتروني
# 6860         فضي       ديزل       خصوصي     فلسطينية           عادي  الكتروني
# 6861      بترولي       ديزل       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# 6862        أبيض       ديزل       عمومي     فلسطينية           عادي  الكتروني
#
# ...

# %%
m=(df.dtypes=='object')
m
# Out:
# لون السيارة             True
# نوع الوقود              True
# أصل السيارة             True
# رخصة السيارة            True
# نوع الجير               True
# الزجاج                  True
# قوة الماتور            False
# عداد السيارة            True
# عدد الركاب              True
# وسيلة الدفع             True
# معروضة                  True
# أصحاب سابقون            True
# إضافات                  True
# سنة الاصدار            False
# سعر السيارة بالشيكل    False
# موديل                   True
# dtype: bool

# %%
#obj_cols list that contain column index (column name) that have obj
obj_cols=list(m[m].index)
obj_cols

# %%
c=0
bad=[]
# 19 شغال
for index in df['عداد السيارة']:
    bad.append(index)
    if index=='شغال':
        c=c+1
c
# Out:
# 19

# %%
# شغال=99999
j=0
while j<len(df):
    if df.loc[j,'عداد السيارة']=='شغال':
        df.loc[j,'عداد السيارة']='99999'
    j=j+1

#اكثر من سيارة=99999
df.loc[847,'عداد السيارة']='99999'
    
#df['عداد السيارة']
#mean()

# %%
#الف و صفر تحويل ل 000
#########index_alf = index_alf , _zero
index_alf=[]
j=0
while j<len(df['عداد السيارة']):
    string_cell=str(df.loc[j,'عداد السيارة'])
    i=0
    while i<len(string_cell):
        if string_cell[i]=='ف':
            print(string_cell,'___',j)
            index_alf.append(j)
            #df.loc[j,'عداد السيارة']=''
        i=i+1
    #df.loc[j,'عداد السيارة']=int(df.loc[j,'عداد السيارة'])
    
    j=j+1
#index_alf
# Out:
# 150 الف ___ 16
# 80 الف ___ 83
# 120 الف ___ 100
# 60الف ___ 181
# 47 الف ___ 207
# 140 الف كيلو متر ___ 270
# 40 الف ___ 359
# 80الف ___ 420
# 91 الف ___ 506
# 150 الف ___ 593
# 60 الف كيلو متر ___ 661
# 27الف كيلو ___ 681
# 78 الف ___ 693
# ١٤٣ الف ___ 701
# 100 الف كيلو ___ 720
# 230 الف كيلو متر ___ 722
# صفر كيلو ___ 786
# 112 الف كيلو ___ 838
# ٧٠٠٠٠ الف كيلو ___ 904
# 92الف كيلو ___ 947
# ٣٥ الف كيلو ___ 1023
# 100الف ___ 1038
# ٢١٠ الاف ___ 1157
# 47 الف ___ 1158
# 350 الف ___ 1172
# 140 الف ___ 1188
# 90000الف فقط ___ 1196
# 90000الف فقط ___ 1196
# ١٩ الف سنويا ___ 1279
# ٩٨ الف ___ 1347
# 39000الف كيلو متر ___ 1466
# ٣٠٠ الف ___ 1504
# 42 الف ___ 1560
# صفر كيلو ___ 1594
# 65 الف ___ 1770
# ٧٠ الف ___ 1790
# 91 الف كم ___ 1820
# 100 الف ___ 1851
# 95 الف ___ 1871
# 130 الف ___ 1873
# 130الف ___ 1989
# ماشيه 80الف كم ___ 1992
# 190الف ___ 1995
# 15 الف ___ 2002
# ٧٠ الف ___ 2077
# 275 ألف كم ___ 2099
# 0 صفر كيلو ___ 2218
# ١٢٠ الف ___ 2334
# 20 الف ___ 2336
# ...

# %%
#alf count 
len(index_alf)
# Out:
# 133

# %%
for index in index_alf:
    string_alf=df.loc[index,'عداد السيارة']
#int alf list
#delete صفر
    alf_list=[int(i)for i in string_alf.split() if i.isdigit()]
    if alf_list==[]:
        string_alf=df.loc[index,'عداد السيارة']
    #الغي كلمة الف
        s=0
        while s<len(string_alf):
            if string_alf[s]=='ا' or string_alf[s]=='أ':
                c=0
                while c<s:
                    alf_list.append(string_alf[c])
                    c=c+1
                break
            s=s+1             
                
#change list into single int 
    var = ''  
    for element in alf_list: 
            var += str(element)
    var=var+'000'
    df.loc[index,'عداد السيارة']=var

# %%
i=0
#len(df)
good=[]
while i<len(df):
    string_A=df.loc[i,'عداد السيارة']
    #int_list
    string_list=[int(j)for j in string_A.split() if j.isdigit()]
    var = ''  
    for element in string_list: 
        var += str(element)
    if var!='':
        price=int(var)
    good.append(price)
    df.loc[i,'عداد السيارة']=price
    i=i+1
    
# int-عداد السيارة

type(df.loc[6666,'عداد السيارة'])
# Out:
# int

# %%
# delete noisy: take previous
i=0
while i<len(df):
    if bad[i]!=good[i]:
        #print(i,"_____(",bad[i],")==========",good[i])
    i=i+1
# Out:
#   Input In [231]
#     i=i+1
#     ^
# IndentationError: expected an indented block

# %%
#missing = mean
#df2 = df["Fee"].mean()

df["عداد السيارة"].mean()
# Out:
# 8.752542152124134e+17

# %%
#missing  (mean=عداد السيارة)
i=0
while i<len(df):
    if df.loc[i,'عداد السيارة']==99999:
        df.loc[i,'عداد السيارة']=df["عداد السيارة"].mean()
    i=i+1

# %%
df = df.drop(columns=['الزجاج' ,'لون السيارة','معروضة'])

# %%
df
# Out:
#      نوع الوقود أصل السيارة رخصة السيارة      نوع الجير  قوة الماتور  \
# 0          ديزل       خصوصي     فلسطينية  نصف اوتوماتيك         2500
# 1         بنزين       خصوصي     فلسطينية      اوتوماتيك         1600
# 2         بنزين       خصوصي     فلسطينية           عادي          906
# 3         بنزين       خصوصي     فلسطينية      اوتوماتيك         1200
# 4          ديزل       خصوصي     فلسطينية      اوتوماتيك         2000
# ...         ...         ...          ...            ...          ...
# 6858     كهرباء       خصوصي     فلسطينية      اوتوماتيك         1000
# 6859       ديزل       عمومي     فلسطينية           عادي         2400
# 6860       ديزل       خصوصي     فلسطينية           عادي         1600
# 6861       ديزل       خصوصي     فلسطينية      اوتوماتيك         2200
# 6862       ديزل       عمومي     فلسطينية           عادي         2500
#
#               عداد السيارة عدد الركاب      وسيلة الدفع أصحاب سابقون  \
# 0                   130000        7+1  إمكانية التقسيط            2
# ...

# %%
# 1= (مؤثرة )فتحة سقف 
i=0
while i<len(df):
    string=df.loc[i,'إضافات']
    search = string.find("فتحة")
    if search != -1:
        #find it
        df.loc[i,'إضافات']=1
    else:
        df.loc[i,'إضافات']=0
    i=i+1
#missing تعبت 0

# %%
df
# Out:
#      نوع الوقود أصل السيارة رخصة السيارة      نوع الجير  قوة الماتور  \
# 0          ديزل       خصوصي     فلسطينية  نصف اوتوماتيك         2500
# 1         بنزين       خصوصي     فلسطينية      اوتوماتيك         1600
# 2         بنزين       خصوصي     فلسطينية           عادي          906
# 3         بنزين       خصوصي     فلسطينية      اوتوماتيك         1200
# 4          ديزل       خصوصي     فلسطينية      اوتوماتيك         2000
# ...         ...         ...          ...            ...          ...
# 6858     كهرباء       خصوصي     فلسطينية      اوتوماتيك         1000
# 6859       ديزل       عمومي     فلسطينية           عادي         2400
# 6860       ديزل       خصوصي     فلسطينية           عادي         1600
# 6861       ديزل       خصوصي     فلسطينية      اوتوماتيك         2200
# 6862       ديزل       عمومي     فلسطينية           عادي         2500
#
#               عداد السيارة عدد الركاب      وسيلة الدفع أصحاب سابقون إضافات  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
#class name
df['نوع الوقود'].unique()
# Out:
# array(['ديزل', 'بنزين', 'هايبرد', 'كهرباء'], dtype=object)

# %%
obj_cols=['نوع الوقود']

# %%
Encoder=LabelEncoder()
df['نوع الوقود']=Encoder.fit_transform(df['نوع الوقود'])

# %%
df['أصل السيارة'].unique()
# Out:
# array(['خصوصي', 'عمومي', 'تأجير', 'تجاري', 'تدريب سياقة', 'حكومي'],
#       dtype=object)

# %%
obj_cols=['أصل السيارة']
Encoder=LabelEncoder()
df['أصل السيارة']=Encoder.fit_transform(df['أصل السيارة'])

# %%
df['رخصة السيارة'].unique()
# Out:
# array(['فلسطينية', 'نمرة صفراء'], dtype=object)

# %%
obj_cols=['رخصة السيارة']
Encoder=LabelEncoder()
df['رخصة السيارة']=Encoder.fit_transform(df['رخصة السيارة'])

# %%
df['نوع الجير'].unique()
# Out:
# array(['نصف اوتوماتيك', 'اوتوماتيك', 'عادي'], dtype=object)

# %%
obj_cols=['نوع الجير']
Encoder=LabelEncoder()
df['نوع الجير']=Encoder.fit_transform(df['نوع الجير'])

# %%
df['وسيلة الدفع'].unique()
# Out:
# array(['إمكانية التقسيط', 'نقدا فقط'], dtype=object)

# %%
obj_cols=['وسيلة الدفع']
Encoder=LabelEncoder()
df['وسيلة الدفع']=Encoder.fit_transform(df['وسيلة الدفع'])

# %%
df['موديل'].unique()
# Out:
# array(['كياسورينتو', 'هوندايافانتي', 'فيات127', 'بيجو208', 'بيامدبليوx3',
#        'اوبلكورسا', 'مرسيدسC200', 'فوردفيستا', 'نيسانباترول',
#        'فوردترانزيت', 'بيجو206+', 'سكودافابيا', 'فيات1998', 'كيابرايد',
#        'بيجوبارتنر', 'فولكسفاجنكادي', 'هوندااكورد', 'اوبلاسكونا',
#        'هوندايسانتافيه', 'هوندايالانترا', 'هوندايi30', 'هوندايتوسان',
#        'سكودارابيد', 'هوندايi40', 'سكودااوكتافيا', 'كيافورتي',
#        'اوبلكاديت', 'هونداياكسنت', 'فولكسفاجنبولو', 'دايولانوس',
#        'فولكسفاجنتوران', 'شفروليهاوبترا', 'دايورايسر', 'رينوR9',
#        'مرسيدسفيتو', 'جييبشيروكي', 'فولكسفاجنكرافيل', 'هوندايجيتس',
#        'فولكسفاجنجولف', 'فولكسفاجنباسات', 'فولكسفاجنترانسبورتر',
#        'اوبلزافيرا', 'سكوداسوبيرب', 'كيابيكانتو', 'فوردفوكس',
#        'دايونوبيرا', 'بيامدبليوX3', 'شفروليهافيو', 'دراجةناريةدراجهسييم',
#        'بيجو305', 'ستروينكسارا', 'هوندايكليك', 'بيامدبليو520',
#        'هوندايi25', 'بيجو307', 'فولكسفاجنCC', 'دايوماتيز', 'مرسيدس220',
# ...

# %%
obj_cols=['موديل']
Encoder=LabelEncoder()
df['موديل']=Encoder.fit_transform(df['موديل'])

# %%
df['إضافات'].unique()
# Out:
# array([1, 0], dtype=object)

# %%
obj_cols=['إضافات']
Encoder=LabelEncoder()
df['إضافات']=Encoder.fit_transform(df['إضافات'])

# %%
df['عدد الركاب'].unique()
# Out:
# array(['7+1', '4+1', '5+1', '٤+١', '8', '6+1', '4+١', '٧', '7,+ 1', '7:1',
#        '1+7', '١+٤', '2+1', '6+١', '6±١', '22', '1+1', '٥+١', '٧+1',
#        '5+2', 'مثال: 4 + 1', '7.1', '7 =1', '٧+١', '1+2', '6x1', '1+٤',
#        '2/1', '8+1', '٨+١', '٦+١', '2', '4+2', '1٠4', '4\\١', '3+1', '1',
#        'اكثر من 10', '9+1'], dtype=object)

# %%
import re
#index=='١+٧'
i=0
while i<len(df):
    my_search=re.search(r'[7٧]',df.loc[i,'عدد الركاب'])
    if my_search!=None:
        df.loc[i,'عدد الركاب']='7+1'
    else:
        my_search=re.search(r'[4٤]',df.loc[i,'عدد الركاب'])
        if my_search!=None:
            df.loc[i,'عدد الركاب']='4+1'
        else:
            my_search=re.search(r'[5٥]',df.loc[i,'عدد الركاب'])
            if my_search!=None:
                df.loc[i,'عدد الركاب']='5+1'
            else:
                my_search=re.search(r'[6٦]',df.loc[i,'عدد الركاب'])
                if my_search!=None:
                    df.loc[i,'عدد الركاب']='6+1'
                else:
                    my_search=re.search(r'[8٨]',df.loc[i,'عدد الركاب'])
                    if my_search!=None:
                        df.loc[i,'عدد الركاب']='8+1'
                    else: 
                        my_search=re.search(r'[3]',df.loc[i,'عدد الركاب'])
                        if my_search!=None:
                            df.loc[i,'عدد الركاب']='3+1'
                        else: 
                            my_search=re.search(r'[2]',df.loc[i,'عدد الركاب'])
                            if my_search!=None:
                                df.loc[i,'عدد الركاب']='2+1'
                           
                   
                        
    i=i+1

# %%
df['عدد الركاب'].unique()
# Out:
# array(['7+1', '4+1', '5+1', '8+1', '6+1', '2+1', '1+1', '3+1', '1',
#        'اكثر من 10', '9+1'], dtype=object)

# %%
df['عدد الركاب']=df['عدد الركاب'].map({'1':0,'1+1':1,2:'2+1','3+1':3,'4+1':4,'5+1':5,6:'6+1','7+1':7,'8+1':8,'9+1':9,'اكثر من 10':10})

# %%
df
# Out:
#       نوع الوقود  أصل السيارة  رخصة السيارة  نوع الجير  قوة الماتور  \
# 0              1            4             0          2         2500
# 1              0            4             0          0         1600
# 2              0            4             0          1          906
# 3              0            4             0          0         1200
# 4              1            4             0          0         2000
# ...          ...          ...           ...        ...          ...
# 6858           2            4             0          0         1000
# 6859           1            5             0          1         2400
# 6860           1            4             0          1         1600
# 6861           1            4             0          0         2200
# 6862           1            5             0          1         2500
#
#               عداد السيارة عدد الركاب  وسيلة الدفع أصحاب سابقون  إضافات  \
# 0                   130000          7            0            2       1
# ...

# %%
df['أصحاب سابقون'].unique()
# Out:
# array(['2', '00', '0', 'يد اولى', '1', 'يد ثانية', '4', 'يد ثانيه', '3',
#        'ثالثة', 'غير منمر استيراد الماني', 'غير منمرة', 'أولى', '٨',
#        'يد اولا', 'يد ثالثة', 'ثانية', 'يد أولى', 'يد سادسة', '5', 'اولى',
#        'صفر', '9', '0000', 'رابعه', '٤', 'يد رابعة', '٢', 'يد ثالثه', '6',
#        '7', '...', 'يد أولى استيراد', 'يد اولي 1', '......', 'ثانيه',
#        'واحد', 'اربعة', 'اولا', '٣', 'غير منمره', 'يد تالته', '٦',
#        'يد رابعه', 'يد ثالثة ( فتيات)', '159000', '12', '-', 'مش منمر',
#        '0 مستورده', 'يد تانيه', '10', 'يد 1', 'مستورد', 'يد 4', '00000',
#        '١', 'استيراد مباشر من كوريا', 'يد خامسة', '٥', 'يد 5', '********',
#        'نعم', 'مش منمرة', 'يد 3', 'يداولى', 'يد أولى وكالة', 'يد خامسه',
#        '٩', '٧', 'يدو اولى', 'للبيع', '8', 'يد واله', 'مش منمره', 'ثالثه',
#        'اول', '11', '٠', 'رابعة', 'منمره', '0مستورد', '03', 'يد 2',
#        'يد ولا', 'يد عاشره', 'يدثانيه', 'لا يوجد', '56', '.', '١١',
# ...

# %%
#الارقام 
i=0
while i<len(df['أصحاب سابقون']):
    a=df.loc[i,'أصحاب سابقون']          
    list=[int(z)for z in a.split() if z.isdigit()]
    var = ''  
    for element in list: 
        var += str(element)
    if var!='':
        num=int(var)
    if num>20:
         df.loc[i,'أصحاب سابقون']="will_be_missing"
            
    i=i+1

# %%
# اولى
i=0
while i<len(df['أصحاب سابقون']):
    a=df.loc[i,'أصحاب سابقون']
#b='اولا'
    b=['١','1','أولى','ولا','اول','اولي','اولا','واله','أولئ','أولي','اةلي','واحد','اوله','يد ١','01','يد ا']
    j=0
    while j<len(b):
        if b[j] in a.lower():
            df.loc[i,'أصحاب سابقون']='يد 1'
            break
        j=j+1
    i=i+1

# %%
#45679
i=0
while i<len(df):
    txt=df.loc[i,'أصحاب سابقون']
    
    if re.search('خمس',txt):
        df.loc[i,'أصحاب سابقون']='يد 5'
        
    if re.search('سابعه',txt):
        df.loc[i,'أصحاب سابقون']='يد 7'
        
    if re.search('ثمانيه',txt):
        df.loc[i,'أصحاب سابقون']='يد 8'
        
    if re.search('تاسعة',txt):
        df.loc[i,'أصحاب سابقون']='يد 9'
        
    if re.search('عاشره',txt):
        df.loc[i,'أصحاب سابقون']='يد 10'
        
    if re.search('خامسة',txt):
        df.loc[i,'أصحاب سابقون']='يد 5'
        
    if re.search('اربعة',txt):
        df.loc[i,'أصحاب سابقون']='يد 4'
        
    if re.search('رابعه',txt):
        df.loc[i,'أصحاب سابقون']='يد 4'
        
    if re.search('4',txt):
        df.loc[i,'أصحاب سابقون']='يد 4'
        
    if re.search('7',txt):
        df.loc[i,'أصحاب سابقون']='يد 7'
        
    if re.search('6',txt):
        df.loc[i,'أصحاب سابقون']='يد 6'
        
    if re.search('5',txt):
        df.loc[i,'أصحاب سابقون']='يد 5'
        
    if re.search('٩',txt):
        df.loc[i,'أصحاب سابقون']='يد 9'
        
    if re.search('٤',txt):
        df.loc[i,'أصحاب سابقون']='يد 4'
        
    if re.search('٥',txt):
        df.loc[i,'أصحاب سابقون']='يد 5'
        
    if re.search('٦',txt):
        df.loc[i,'أصحاب سابقون']='يد 6'
        
    if re.search('٨',txt):
        df.loc[i,'أصحاب سابقون']='يد 8'
    i=i+1

# %%
#023
i=0
while i<len(df):
    string=df.loc[i,'أصحاب سابقون']
    search = string.find("ثان")
    if search!=-1 : 
        df.loc[i,'أصحاب سابقون']='يد 2'
    else:
        search = string.find("٢")
        if search!=-1 : 
              df.loc[i,'أصحاب سابقون']='يد 2'
        else:
            search = string.find("ثال")
            if search!=-1 : 
                df.loc[i,'أصحاب سابقون']='يد 3'
            else:
                search = string.find("٣")
                if search!=-1 : 
                    df.loc[i,'أصحاب سابقون']='يد 3'
                else:
                    search = string.find("3")
                    if search!=-1 : 
                        df.loc[i,'أصحاب سابقون']='يد 3'
                    else:
                        #استيراد 
                        search = string.find("ست")
                        if search!=-1 : 
                            df.loc[i,'أصحاب سابقون']='يد 0'
                        else:
                            search = string.find("٠")
                            if search!=-1 : 
                                df.loc[i,'أصحاب سابقون']='يد 0'
                            else:
                                search = string.find("صفر")
                                if search!=-1 : 
                                    df.loc[i,'أصحاب سابقون']='يد 0'
                                else:
                                    search = string.find("0")
                                    if search!=-1 : 
                                        df.loc[i,'أصحاب سابقون']='يد 0'
                                    else:
                                        search = string.find("Zero")
                                        if search!=-1 : 
                                            df.loc[i,'أصحاب سابقون']='يد 0'
                                        else:
                                            search = string.find("تال")
                                            if search!=-1 : 
                                                df.loc[i,'أصحاب سابقون']='يد 3'
                                            else:
                                                search = string.find("تان")
                                                if search!=-1 : 
                                                    df.loc[i,'أصحاب سابقون']='يد 2'
                                                else:
                                                    search = string.find("2")
                                                    if search!=-1 : 
                                                        df.loc[i,'أصحاب سابقون']='يد 2'
            
            
            
            
           
    i=i+1

# %%
df['أصحاب سابقون']=df['أصحاب سابقون'].map({'يد 0':0,
                                          'يد 1':1,
                                          'يد 2':2,
                                          'يد 3':3,
                                          'يد 4':4,
                                          'يد 5':5,
                                          'يد 6':6,
                                          'يد 7':7,
                                          'يد 8':8,
                                          'يد 9':9,
                                          'يد 10':10})

# %%
df
# Out:
#       نوع الوقود  أصل السيارة  رخصة السيارة  نوع الجير  قوة الماتور  \
# 0              1            4             0          2         2500
# 1              0            4             0          0         1600
# 2              0            4             0          1          906
# 3              0            4             0          0         1200
# 4              1            4             0          0         2000
# ...          ...          ...           ...        ...          ...
# 6858           2            4             0          0         1000
# 6859           1            5             0          1         2400
# 6860           1            4             0          1         1600
# 6861           1            4             0          0         2200
# 6862           1            5             0          1         2500
#
#               عداد السيارة  عدد الركاب  وسيلة الدفع  أصحاب سابقون  إضافات  \
# 0                   130000           7            0           2.0       1
# ...

# %%
df['عداد السيارة'] = df['عداد السيارة'].astype(float)

# %% [markdown]
# #solving outlier

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df.describe()
# Out:
#         نوع الوقود  أصل السيارة  رخصة السيارة    نوع الجير  قوة الماتور  \
# count  6863.000000  6863.000000   6863.000000  6863.000000  6863.000000
# mean      0.428530     3.902229      0.010928     0.498470  1740.456943
# std       0.515102     0.810831      0.103973     0.549997   589.505339
# min       0.000000     0.000000      0.000000     0.000000   106.000000
# 25%       0.000000     4.000000      0.000000     0.000000  1400.000000
# 50%       0.000000     4.000000      0.000000     0.000000  1600.000000
# 75%       1.000000     4.000000      0.000000     1.000000  2000.000000
# max       3.000000     5.000000      1.000000     2.000000  9000.000000
#
#        عداد السيارة   عدد الركاب  وسيلة الدفع  أصحاب سابقون       إضافات  \
# count  6.863000e+03  6863.000000  6863.000000   6863.000000  6863.000000
# mean   1.166920e+18     4.107533     0.629754      1.959493     0.264316
# std    7.250683e+19     0.773603     0.482906      1.512155     0.441000
# ...

# %%
def plot_boxplot(df,ft):
    df.boxplot(column=[ft])
    plt.grid(False)
    plt.show()

# %%
plot_boxplot(df,'قوة الماتور')

# %%
plot_boxplot(df,'سعر السيارة بالشيكل')

# %%
#Remove it
def outliers(df,ft):
        Q1=df[ft].quantile(0.25)
        Q3=df[ft].quantile(0.75)
        IQR=Q3-Q1
        
        lower_bound=Q1-1.5*IQR
        upper_bound=Q3+1.5*IQR
        
        ls=df.index[(df[ft]<lower_bound)|(df[ft]>upper_bound)]
        return ls

# %%
#create an empty list to store the output indices from multiple columns
index_list=[]
for feature in['عداد السيارة','قوة الماتور','سعر السيارة بالشيكل']:
    index_list.extend(outliers(df,feature))

# %%
index_list
# Out:
# [5971,
#  8,
#  47,
#  74,
#  91,
#  92,
#  112,
#  115,
#  119,
#  135,
#  164,
#  171,
#  186,
#  189,
#  193,
#  200,
#  212,
#  217,
#  220,
#  238,
#  251,
#  273,
#  291,
#  369,
#  384,
#  408,
#  412,
#  436,
#  445,
#  462,
#  476,
#  482,
#  500,
#  503,
#  511,
#  538,
#  562,
#  569,
#  571,
#  585,
#  596,
#  599,
#  608,
#  612,
#  625,
#  628,
#  688,
#  692,
#  726,
#  731,
#  756,
#  764,
#  768,
#  793,
#  798,
#  808,
#  839,
#  863,
#  868,
#  876,
#  882,
#  891,
#  929,
#  1006,
#  1052,
#  1068,
#  1082,
#  1092,
#  1096,
#  1124,
#  1134,
#  1135,
#  1143,
#  1152,
#  1171,
#  1181,
#  1185,
#  1187,
#  1192,
#  1203,
#  1226,
#  1242,
#  1251,
#  1252,
#  1275,
#  1303,
#  1308,
#  1370,
#  1378,
#  1381,
#  1385,
#  1389,
#  1399,
#  1407,
#  1409,
#  1417,
#  1421,
#  1431,
#  1434,
#  1438,
#  1447,
#  1468,
#  1494,
#  1504,
#  1516,
#  1542,
#  1556,
#  1562,
#  1586,
#  1636,
#  1656,
#  1663,
#  1666,
#  1690,
#  1697,
#  1729,
#  1733,
#  1758,
# ...

# %%
#remove
def remove (df,ls):
    ls=sorted(set(ls))
    df=df.drop(ls)
    return df

# %%
df_cleaned=remove(df,index_list)

# %%
df_cleaned.shape
# Out:
# (6219, 13)

# %%
plot_boxplot(df_cleaned,'قوة الماتور')
#no outl

# %%
plot_boxplot(df_cleaned,'عداد السيارة')
#no outl

# %%
df
# Out:
#       نوع الوقود  أصل السيارة  رخصة السيارة  نوع الجير  قوة الماتور  \
# 0              1            4             0          2         2500
# 1              0            4             0          0         1600
# 2              0            4             0          1          906
# 3              0            4             0          0         1200
# 4              1            4             0          0         2000
# ...          ...          ...           ...        ...          ...
# 6858           2            4             0          0         1000
# 6859           1            5             0          1         2400
# 6860           1            4             0          1         1600
# 6861           1            4             0          0         2200
# 6862           1            5             0          1         2500
#
#       عداد السيارة  عدد الركاب  وسيلة الدفع  أصحاب سابقون  إضافات  \
# 0     1.300000e+05           7            0           2.0       1
# ...

# %% [markdown]
# Correlation

# %%
df.corr()
# Out:
#                      نوع الوقود  أصل السيارة  رخصة السيارة  نوع الجير  \
# نوع الوقود             1.000000     0.067880     -0.027591   0.099278
# أصل السيارة            0.067880     1.000000     -0.018440  -0.006381
# رخصة السيارة          -0.027591    -0.018440      1.000000  -0.029014
# نوع الجير              0.099278    -0.006381     -0.029014   1.000000
# قوة الماتور            0.363965    -0.079632      0.017953  -0.063387
# عداد السيارة          -0.009938     0.001541     -0.001127  -0.010402
# عدد الركاب             0.175448     0.093199     -0.030918   0.068546
# وسيلة الدفع           -0.079739    -0.006117      0.063182  -0.050692
# أصحاب سابقون          -0.054233     0.006872      0.000962   0.117325
# إضافات                 0.029925     0.021745     -0.015331  -0.236260
# سنة الاصدار            0.146967     0.059784     -0.041472  -0.288814
# سعر السيارة بالشيكل    0.230806     0.006479     -0.091889  -0.203238
# ...

# %%
import seaborn as sns 
sns.pairplot(df)

# %%
#positive
plt.scatter(df['سنة الاصدار'],df['سعر السيارة بالشيكل'])

# %%
sns.regplot(x='سنة الاصدار',y='سعر السيارة بالشيكل',data=df)
# Out:
# <AxesSubplot:xlabel='سنة الاصدار', ylabel='سعر السيارة بالشيكل'>

# %%
#negtive
plt.scatter(df['أصحاب سابقون'],df['سعر السيارة بالشيكل'])

# %%
sns.regplot(x='أصحاب سابقون',y='سعر السيارة بالشيكل',data=df)
# Out:
# <AxesSubplot:xlabel='أصحاب سابقون', ylabel='سعر السيارة بالشيكل'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6863 entries, 0 to 6862
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   نوع الوقود           6863 non-null   int32
#  1   أصل السيارة          6863 non-null   int32
#  2   رخصة السيارة         6863 non-null   int32
#  3   نوع الجير            6863 non-null   int32
#  4   قوة الماتور          6863 non-null   int64
#  5   عداد السيارة         6863 non-null   float64
#  6   عدد الركاب           6863 non-null   int64
#  7   وسيلة الدفع          6863 non-null   int32
#  8   أصحاب سابقون         6863 non-null   float64
#  9   إضافات               6863 non-null   int32
#  10  سنة الاصدار          6863 non-null   int64
#  11  سعر السيارة بالشيكل  6863 non-null   int64
#  12  موديل                6863 non-null   int32
# dtypes: float64(2), int32(7), int64(4)
# memory usage: 509.5 KB

# %%
x=df.iloc[:,[0,1,2,3,4,5,6,7,9,10,12]].values
y=df.iloc[:,11].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
x_scaler=StandardScaler()
x_train=x_scaler.fit_transform(x_train)
x_test=x_scaler.fit_transform(x_test)

# %%
x_test
# Out:
# array([[-0.83330166,  0.13564152, -0.10002942, ...,  1.62820878,
#         -2.54138507, -1.85806664],
#        [ 1.09125506,  0.13564152, -0.10002942, ..., -0.61417185,
#          0.39145258,  0.27171283],
#        [ 1.09125506,  0.13564152, -0.10002942, ..., -0.61417185,
#          0.72985692,  1.46717487],
#        ...,
#        [ 1.09125506,  0.13564152, -0.10002942, ...,  1.62820878,
#         -0.05975321, -1.14427134],
#        [-0.83330166,  0.13564152, -0.10002942, ..., -0.61417185,
#         -3.21819376, -0.27959248],
#        [ 1.09125506,  0.13564152, -0.10002942, ..., -0.61417185,
#          1.06826126,  0.39938353]])

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(3) # Define classifier
knn.fit(x_train, y_train) # Train model

# Make predictions
y_train_pred = knn.predict(x_train)
y_test_pred = knn.predict(x_test)

# Training set performance
knn_train_accuracy = accuracy_score(y_train, y_train_pred) # Calculate Accuracy

####### Test set performance
knn_test_accuracy = accuracy_score(y_test, y_test_pred) # Calculate Accuracy

print('Model performance for Training set')
print('- Accuracy: %s' % knn_train_accuracy)
print('----------------------------------')
print('Model performance for Test set')
print('- Accuracy: %s' % knn_test_accuracy)
# Out:
# Model performance for Training set
# - Accuracy: 0.380998639984457
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.03613053613053613

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(max_depth=5) # Define classifier
dt.fit(x_train, y_train) # Train model

# Make predictions
y_train_pred = dt.predict(x_train)
y_test_pred = dt.predict(x_test)

# Training set performance
dt_train_accuracy = accuracy_score(y_train, y_train_pred) # Calculate Accuracy

# Test set performance
dt_test_accuracy = accuracy_score(y_test, y_test_pred) # Calculate Accuracy

print('Model performance for Training set')
print('- Accuracy: %s' % dt_train_accuracy)
print('----------------------------------')
print('Model performance for Test set')
print('- Accuracy: %s' % dt_test_accuracy)
# Out:
# Model performance for Training set
# - Accuracy: 0.07790946182242083
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.05011655011655012

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
#applying polynomial regression degree 2
poly = PolynomialFeatures(degree=2, include_bias=True)
x_train_trans = poly.fit_transform(x_train)
x_test_trans = poly.transform(x_test)
#include bias parameter
lr = LinearRegression()
lr.fit(x_train_trans, y_train)
y_train_pred = lr.predict(x_train_trans)
y_test_pred = lr.predict(x_test_trans)

# %%
from sklearn.metrics import r2_score
reg_train_accuracy=r2_score(y_train,y_train_pred)
reg_test_accuracy=r2_score(y_test,y_test_pred)
reg_test_accuracy
print('Model performance for Training set')
print('- Accuracy: %s' % reg_train_accuracy)
print('----------------------------------')
print('Model performance for Test set')
print('- Accuracy: %s' % reg_test_accuracy)
# Out:
# Model performance for Training set
# - Accuracy: 0.4295984270600536
# ----------------------------------
# Model performance for Test set
# - Accuracy: -47586331103705.62

# %% [markdown]
# #Train Result

# %%
acc_train_list = {'knn':knn_train_accuracy,
'dt': dt_train_accuracy,
'reg':reg_train_accuracy
}

acc_train_list
# Out:
# {'knn': 0.380998639984457,
#  'dt': 0.07790946182242083,
#  'reg': 0.4295984270600536}

# %%
acc_train_df = pd.DataFrame.from_dict(acc_train_list, orient='index', columns=['Accuracy'])

# %%
acc_train_df
# Out:
#      Accuracy
# knn  0.380999
# dt   0.077909
# reg  0.429598

# %%
#Test Result

# %%
#result
acc_test_list = {'knn':knn_test_accuracy,
'dt': dt_test_accuracy,
'reg':reg_test_accuracy
#'Regressor':reg_test_accuracy,
}

acc_test_list
# Out:
# {'knn': 0.03613053613053613,
#  'dt': 0.05011655011655012,
#  'reg': -47586331103705.62}

# %%
acc_test_df = pd.DataFrame.from_dict(acc_test_list, orient='index', columns=['Accuracy'])
acc_test_df
# Out:
#          Accuracy
# knn  3.613054e-02
# dt   5.011655e-02
# reg -4.758633e+13

# %% [markdown]
# # Pickling The Model file For Deployment

# %%
import pickle

# %%
pickle.dump(linreg,open('regmodel.pkl','wb'))

# %%
pickled_model=pickle.load(open('regmodel.pkl','rb'))
